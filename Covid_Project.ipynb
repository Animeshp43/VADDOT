# %% [markdown]
# <a href="https://colab.research.google.com/github/Animeshp43/VADDOT/blob/main/Covid_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from  sklearn.metrics import accuracy_score

# %%
df_cp=pd.read_excel("Demographic CONTROL.xlsx")

# %%
df_cp
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0          ID     Gender        Age
# 1          11          F         49
# 2          12          F         55
# 3          13          F         52
# 4          14          F         10
# 5          15          M         52
# 6          16          F         49
# 7          17          F         52
# 8          18          M         22
# 9          19          F         49
# 10         21          M         56
# 11         24          F         55
# 12         25          F         55
# 13         26          F         55
# 14         27          M         25
# 15         29          F         55
# 16         30          F         56
# 17         31          F         54
# 18         34          F         29
# 19         37          F         45
# 20         38          F         51
# 21         39          M         13
# 22         40          M         55
# 23         41          F         56
# 24         42          M         55
# ...

# %%
df_cp1=pd.read_excel("Demographic COVID.xlsx")

# %%
df_cp1
# Out:
#     Unnamed: 0    Unnamed: 1 Unnamed: 2  \
# 0          NaN            ID     Gender
# 1          NaN             1          M
# 2          NaN             2          F
# 3          NaN             3          F
# 4          NaN             4          F
# 5          NaN             5          M
# 6          NaN             6          F
# 7          NaN             7          M
# 8          NaN             8          M
# 9          NaN             9          F
# 10         NaN            10          M
# 11         NaN            11          M
# 12         NaN            12          F
# 13         NaN            13          M
# 14         NaN            14          M
# 15         NaN            15          F
# 16         NaN            16          M
# 17         NaN            17          M
# 18         NaN            18          F
# 19         NaN            19          F
# 20         NaN            20          M
# 21         NaN            21          M
# ...

# %%
df_cp2=pd.read_excel("MFCCDescription.xlsx")

# %%
df_cp2
# Out:
#    Unnamed: 0 Unnamed: 1                Unnamed: 2  \
# 0      Column        NaN                 Parameter
# 1           1          A                   Phoneme
# 2           2          B  Day / control subjedt ID
# 3           3          C                     MFCC0
# 4           4          D                     MFCC1
# 5           5          E                     MFCC2
# 6           6          F                     MFCC3
# 7           7          G                     MFCC4
# 8           8          H                     MFCC5
# 9           9          I                     MFCC6
# 10         10          J                     MFCC7
# 11         11          K                     MFCC8
# 12         12          L                     MFCC9
# 13         13          M                    MFCC10
# 14         14          N                    MFCC11
# 15         15          O                    MFCC12
# 16         16          P                     Label
#
# ...

# %%
df_cp.shape
# Out:
# (49, 3)

# %%
df_cp3=pd.read_excel("paramDescription.xlsx")

# %%
df_cp3
# Out:
#    Unnamed: 0 Unnamed: 1                Unnamed: 2  \
# 0      Column        NaN                 Parameter
# 1           1          A                   Phoneme
# 2           2          B  Day / control subjedt ID
# 3           3          C                Jitter abs
# 4           4          D                Jitter rel
# 5           5          E               Shimmer abs
# 6           6          F               Shimmer rel
# 7           7          G                std(Pitch)
# 8           8          H                       HNR
# 9           9          I                       NHR
# 10         10          J                  mean(F1)
# 11         11          K                  mean(F2)
# 12         12          L                  mean(F3)
# 13         13          M                  mean(F4)
# 14         14          N                   std(F1)
# 15         15          O                   std(F2)
# 16         16          P                   std(F3)
# ...

# %%
df_cp.shape
# Out:
# (49, 3)

# %%
df_cp.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0         ID     Gender        Age
# 1         11          F         49
# 2         12          F         55
# 3         13          F         52
# 4         14          F         10

# %%
df_cp1.shape
# Out:
# (47, 27)

# %%
df_cp2.shape
# Out:
# (17, 9)

# %%
df_cp3.shape
# Out:
# (25, 9)

# %%
df_cp.shape
# Out:
# (49, 3)

# %%
df_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  49 non-null     object
#  1   Unnamed: 1  49 non-null     object
#  2   Unnamed: 2  49 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
df_cp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   44 non-null     object
#  2   Unnamed: 2   41 non-null     object
#  3   Unnamed: 3   44 non-null     object
#  4   Unnamed: 4   41 non-null     object
#  5   Unnamed: 5   29 non-null     object
#  6   Unnamed: 6   20 non-null     object
#  7   Unnamed: 7   20 non-null     object
#  8   Unnamed: 8   13 non-null     object
#  9   Unnamed: 9   18 non-null     object
#  10  Unnamed: 10  16 non-null     object
#  11  Unnamed: 11  12 non-null     object
#  12  Unnamed: 12  11 non-null     object
#  13  Unnamed: 13  14 non-null     object
#  14  Unnamed: 14  9 non-null      object
#  15  Unnamed: 15  2 non-null      object
#  16  Unnamed: 16  10 non-null     object
#  17  Unnamed: 17  12 non-null     object
# ...

# %%
df_cp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  17 non-null     object
#  1   Unnamed: 1  16 non-null     object
#  2   Unnamed: 2  17 non-null     object
#  3   Unnamed: 3  4 non-null      object
#  4   Unnamed: 4  2 non-null      object
#  5   Unnamed: 5  1 non-null      object
#  6   Unnamed: 6  1 non-null      object
#  7   Unnamed: 7  1 non-null      object
#  8   Unnamed: 8  1 non-null      object
# dtypes: object(9)
# memory usage: 1.3+ KB

# %%
df_cp3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25 non-null     object
#  1   Unnamed: 1  24 non-null     object
#  2   Unnamed: 2  25 non-null     object
#  3   Unnamed: 3  25 non-null     object
#  4   Unnamed: 4  2 non-null      object
#  5   Unnamed: 5  1 non-null      object
#  6   Unnamed: 6  1 non-null      object
#  7   Unnamed: 7  1 non-null      object
#  8   Unnamed: 8  1 non-null      object
# dtypes: object(9)
# memory usage: 1.9+ KB

# %%
df_cp.describe()
# Out:
#        Unnamed: 0 Unnamed: 1  Unnamed: 2
# count          49         49          49
# unique         49          3          29
# top            ID          F          55
# freq            1         27          10

# %%
df_cp.isnull().sum()
# Out:
# Unnamed: 0    0
# Unnamed: 1    0
# Unnamed: 2    0
# dtype: int64

# %%
df_cp1.isnull().sum()
# Out:
# Unnamed: 0     47
# Unnamed: 1      3
# Unnamed: 2      6
# Unnamed: 3      3
# Unnamed: 4      6
# Unnamed: 5     18
# Unnamed: 6     27
# Unnamed: 7     27
# Unnamed: 8     34
# Unnamed: 9     29
# Unnamed: 10    31
# Unnamed: 11    35
# Unnamed: 12    36
# Unnamed: 13    33
# Unnamed: 14    38
# Unnamed: 15    45
# Unnamed: 16    37
# Unnamed: 17    35
# Unnamed: 18    38
# Unnamed: 19    37
# Unnamed: 20    44
# Unnamed: 21    40
# Unnamed: 22    44
# Unnamed: 23    45
# Unnamed: 24    43
# Unnamed: 25    45
# Unnamed: 26    45
# dtype: int64

# %%
df_cp2.isnull().sum()
# Out:
# Unnamed: 0     0
# Unnamed: 1     1
# Unnamed: 2     0
# Unnamed: 3    13
# Unnamed: 4    15
# Unnamed: 5    16
# Unnamed: 6    16
# Unnamed: 7    16
# Unnamed: 8    16
# dtype: int64

# %%
df_cp3.isnull().sum()
# Out:
# Unnamed: 0     0
# Unnamed: 1     1
# Unnamed: 2     0
# Unnamed: 3     0
# Unnamed: 4    23
# Unnamed: 5    24
# Unnamed: 6    24
# Unnamed: 7    24
# Unnamed: 8    24
# dtype: int64
